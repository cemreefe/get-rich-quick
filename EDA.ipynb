# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/crypto/btc-usd_2012-2018.csv')
df.head()
# Out:
#            ds    y
# 0  2012-06-01  5.3
# 1  2012-06-02  5.3
# 2  2012-06-03  5.2
# 3  2012-06-04  5.3
# 4  2012-06-05  5.4

# %%
price_daily = list(df['y'])

# %%
plt.title('BTC / USD Exchange Rate')
plt.ylabel('Bitcoin Price (USD)')
plt.xlabel('Day')
plt.plot(price_daily)

# %%
plt.plot(price_daily[1600:1800])
